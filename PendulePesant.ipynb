# %% [markdown]
# # Pendule pesant

# %%
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
t = np.linspace(0, 10, 1000)
f0 = 1
omega = 2 * np.pi * f0
theta = np.cos(omega * t)
plt.plot(theta)
